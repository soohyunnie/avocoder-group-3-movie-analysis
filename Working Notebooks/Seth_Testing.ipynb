# %%
import pandas as pd

# %%
# !ls data
# Out:
# Untitled.ipynb
# Untitled1.ipynb
# bom.movie_gross.csv.gz
# imdb.name.basics.csv.gz
# imdb.title.akas.csv.gz
# imdb.title.basics.csv.gz
# imdb.title.crew.csv.gz
# imdb.title.principals.csv.gz
# imdb.title.ratings.csv.gz
# rt.movie_info.tsv.gz
# rt.reviews.tsv.gz
# tmdb.movies.csv.gz
# tn.movie_budgets.csv.gz

# %%
df_bom = pd.read_csv('data/bom.movie_gross.csv.gz')
df_bom.sample(3)
# Out:
#                 title studio  domestic_gross foreign_gross  year
# 1754            Frank  Magn.        645000.0           NaN  2014
# 1414  Spinning Plates    TFA        112000.0           NaN  2013
# 2643      Fire at Sea     KL        121000.0           NaN  2016

# %%
df_bom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
rt_movie_info = pd.read_csv('data/rt.movie_info.tsv.gz',sep='\t',index_col='id')
rt_movie_info.sample(3)
# Out:
#                                                synopsis rating  \
# id
# 531   In this adventure, set in the wilds of Montana...     PG
# 1781  Four young musicians attempt to find success a...  PG-13
# 716                                 In this Pedro Almod     NR
#
#                                                   genre           director  \
# id
# 531   Action and Adventure|Drama|Mystery and Suspens...         Tab Murphy
# 1781   Comedy|Drama|Musical and Performing Arts|Romance  Peter Bogdanovich
# 716                  Art House and International|Comedy                NaN
#
#                writer  theater_date      dvd_date currency box_office  \
# id
# 531        Tab Murphy   Sep 8, 1995  Jan 15, 2002      NaN        NaN
# 1781  Carol Heikkinen  Jul 16, 1993   Mar 7, 2006      NaN        NaN
# 716               NaN   Jan 1, 1983   Sep 9, 2003      NaN        NaN
#
#           runtime studio
# id
# 531   117 minutes    NaN
# 1781  116 minutes    NaN
# 716   116 minutes    NaN

# %%
rt_reviews = pd.read_csv('data/rt.reviews.tsv.gz', sep='\t', encoding="latin-1",index_col=0)
rt_reviews.sample(3)
# Out:
#                                                 review rating   fresh  \
# id
# 563  Don't bother asking how an Ivy League guy woul...    NaN  rotten
# 188  It's a slight and modest flick that occasional...    NaN   fresh
# 940  Strange. "Tim Burton's Corpse Bride" takes off...    1/4  rotten
#
#              critic  top_critic            publisher                date
# id
# 563    Teresa Wiltz           1      Washington Post    February 4, 2005
# 188  Mark Demetrius           0  FILMINK (Australia)    October 18, 2012
# 940      Linda Cook           0       KWQC-TV (Iowa)  September 27, 2005

# %%
df_imdb_names = pd.read_csv('data/imdb.name.basics.csv.gz')
df_imdb_names.sample(3)
# seems to be about different workers in the movie industry
# Out:
#            nconst     primary_name  birth_year  death_year  \
# 436700  nm8340804  Munson Campbell         NaN         NaN
# 497466  nm8747312   Dariush Rahimi         NaN         NaN
# 9223    nm1228312   Dahmenah Mingo         NaN         NaN
#
#               primary_profession                         known_for_titles
# 436700                       NaN                                      NaN
# 497466                    writer                                tt4842228
# 9223    producer,director,writer  tt0186547,tt1529267,tt2191745,tt4530346

# %%
df_imdb_title_basics = pd.read_csv('data/imdb.title.basics.csv.gz')
df_imdb_title_basics.sample(3)
# Out:
#           tconst    primary_title   original_title  start_year  \
# 36905  tt2342229          Neptune          Neptune        2012
# 43102  tt2571310  Cycle on Ceylon  Cycle on Ceylon        2012
# 31127  tt2181839        Billi Pig        Billi Pig        2012
#
#        runtime_minutes                         genres
# 36905             65.0                  Horror,Sci-Fi
# 43102             53.0  Adventure,Documentary,History
# 31127             98.0                         Comedy

# %%
df_imdb_crew = pd.read_csv('data/imdb.title.crew.csv.gz')
df_imdb_crew.sample(3)
# Seems to be a connecting table from title_basics tables to names (tconst to nconst)
# Out:
#            tconst            directors              writers
# 53125   tt4817938            nm7423262            nm7423262
# 136355  tt2262161            nm0203993  nm0316514,nm0203993
# 136500  tt2363070  nm4737469,nm4095276  nm4737469,nm4095276

# %%
df_imdb_principals = pd.read_csv('data/imdb.title.principals.csv.gz')
df_imdb_principals.sample(3)
# seems to be the jobs in the films
# Out:
#             tconst  ordering     nconst  category  job  characters
# 257341   tt1690455         1  nm0312217     actor  NaN     ["Abe"]
# 442686   tt4328680         2  nm4650882   actress  NaN  ["Anjali"]
# 1019644  tt8178198         4  nm6504496  director  NaN         NaN

# %%
df_imdb_ratings = pd.read_csv('data/imdb.title.ratings.csv.gz')
df_imdb_ratings.sample(3)
# Ratings col - let's circle back to this later...
# Out:
#           tconst  averagerating  numvotes
# 63842  tt3752766            5.0       184
# 70715  tt2953530            7.2        13
# 44015  tt6788622            8.4        97

# %%
df_tmdb_movies = pd.read_csv('data/tmdb.movies.csv.gz',index_col='Unnamed: 0')
df_tmdb_movies.sample(3)
# another db with movies, has some popularity score but not sure how to inerpret that
# Out:
#       genre_ids      id original_language  \
# 14071        []  312155                en
# 7708    [10402]  295250                en
# 11960      [35]  263913                en
#
#                                        original_title  popularity  \
# 14071                                  Merely Players       0.600
# 7708   Neil Young with Crazy Horse - Psychedelic Pill       0.600
# 11960                                       Balls Out       2.505
#
#       release_date                                           title  \
# 14071   2014-12-16                                  Merely Players
# 7708    2012-11-19  Neil Young with Crazy Horse - Psychedelic Pill
# 11960   2014-04-19                                       Balls Out
#
#        vote_average  vote_count
# 14071           3.0           1
# 7708            4.3           2
# 11960           4.2          21

# %%
df_the_nums = pd.read_csv('data/tn.movie_budgets.csv.gz')
df_the_nums.sample(3)
# This has info on budget, dom and world gross (reminder - world is dom + foreign)
# Out:
#       id  release_date                  movie production_budget  \
# 5691  92  May 18, 2012  Indie Game: The Movie          $100,000
# 5182  83  Aug 28, 2012             Below Zero        $1,200,000
# 3761  62  Nov 11, 2011            Melancholia        $9,400,000
#
#      domestic_gross worldwide_gross
# 5691             $0              $0
# 5182             $0              $0
# 3761     $3,030,848     $21,817,298

# %% [markdown]
# We will use the following tables to determine the correlation between Production Budget and Gross:
#
# df_the_nums
#
# df_imdb_title_basics
#
# bom_df

# %%
print(df_the_nums.info(),'\n\n')
print(df_imdb_title_basics.info(),'\n\n')
print(df_bom.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
# ...

# %%
df_the_nums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_the_nums.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
df_the_nums['production_budget'].strip('$')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-e89b6eb7837a> in <module>
# ----> 1 df_the_nums['production_budget'].strip('$')
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strip'
