# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movie_gross = pd.read_csv('data/bom.movie_gross.csv.gz')
movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
name_basics = pd.read_csv('data/imdb.name.basics.csv.gz')
name_basics.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
title_akas = pd.read_csv('data/imdb.title.akas.csv.gz')
title_akas
# Out:
#          title_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru    NaN
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención    NaN
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
# ...

# %%
title_basics = pd.read_csv('data/imdb.title.basics.csv.gz')
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
title_crew = pd.read_csv('data/imdb.title.crew.csv.gz')
title_crew.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
title_principals = pd.read_csv('data/imdb.title.principals.csv.gz')
title_principals.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
title_ratings = pd.read_csv('data/imdb.title.ratings.csv.gz')
title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
movie_info = pd.read_csv('data/rt.movie_info.tsv.gz',sep='\t')
movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
rt_reviews = pd.read_csv('data/rt.reviews.tsv.gz', sep='\t', encoding="latin-1")
rt_reviews.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
tmdb_movies = pd.read_csv('data/tmdb.movies.csv.gz')
tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
movie_budgets = pd.read_csv('data/tn.movie_budgets.csv.gz')
movie_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# Genre by profit

# %%
profit = movie_budgets.merge(title_basics, left_on='movie', right_on='primary_title')
profit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3815 entries, 0 to 3814
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3815 non-null   int64
#  1   release_date       3815 non-null   object
#  2   movie              3815 non-null   object
#  3   production_budget  3815 non-null   object
#  4   domestic_gross     3815 non-null   object
#  5   worldwide_gross    3815 non-null   object
#  6   tconst             3815 non-null   object
#  7   primary_title      3815 non-null   object
#  8   original_title     3814 non-null   object
#  9   start_year         3815 non-null   int64
#  10  runtime_minutes    3328 non-null   float64
#  11  genres             3743 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 387.5+ KB

# %%
condensed_profit = profit[['movie', 'primary_title', 'original_title', 'genres', 'production_budget', 'domestic_gross', 'worldwide_gross']]

# %%
condensed_profit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3815 entries, 0 to 3814
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie              3815 non-null   object
#  1   primary_title      3815 non-null   object
#  2   original_title     3814 non-null   object
#  3   genres             3743 non-null   object
#  4   production_budget  3815 non-null   object
#  5   domestic_gross     3815 non-null   object
#  6   worldwide_gross    3815 non-null   object
# dtypes: object(7)
# memory usage: 238.4+ KB

# %%
condensed_profit.head(15)
# Out:
#                                           movie  \
# 0                                        Avatar
# 1   Pirates of the Caribbean: On Stranger Tides
# 2                                  Dark Phoenix
# 3                       Avengers: Age of Ultron
# 4                        Avengers: Infinity War
# 5                                Justice League
# 6                                       Spectre
# 7                         The Dark Knight Rises
# 8                       Solo: A Star Wars Story
# 9                               The Lone Ranger
# 10                                  John Carter
# 11                                      Tangled
# 12                   Captain America: Civil War
# 13           Batman v Superman: Dawn of Justice
# 14            The Hobbit: An Unexpected Journey
#
#                                   primary_title  \
# 0                                        Avatar
# 1   Pirates of the Caribbean: On Stranger Tides
# ...

# %%
condensed_profit = condensed_profit.dropna(subset=['genres'])

# %%
condensed_profit['production_budget'] = condensed_profit['production_budget'].str.replace(',', '').str[1:].astype(float)
condensed_profit['domestic_gross'] = condensed_profit['domestic_gross'].str.replace(',', '').str[1:].astype(float)
condensed_profit['worldwide_gross'] = condensed_profit['worldwide_gross'].str.replace(',', '').str[1:].astype(float)

# %%
condensed_profit['profit'] = condensed_profit['worldwide_gross'] - condensed_profit['production_budget']
condensed_profit.head()
# Out:
#                                          movie  \
# 0                                       Avatar
# 1  Pirates of the Caribbean: On Stranger Tides
# 2                                 Dark Phoenix
# 3                      Avengers: Age of Ultron
# 4                       Avengers: Infinity War
#
#                                  primary_title  \
# 0                                       Avatar
# 1  Pirates of the Caribbean: On Stranger Tides
# 2                                 Dark Phoenix
# 3                      Avengers: Age of Ultron
# 4                       Avengers: Infinity War
#
#                                 original_title                    genres  \
# 0                                        Abatâ                    Horror
# 1  Pirates of the Caribbean: On Stranger Tides  Action,Adventure,Fantasy
# 2                                 Dark Phoenix   Action,Adventure,Sci-Fi
# 3                      Avengers: Age of Ultron   Action,Adventure,Sci-Fi
# ...

# %%
condensed_profit['net_profit_margin'] = condensed_profit['profit'] / condensed_profit['worldwide_gross']
condensed_profit.head()
# Out:
#                                          movie  \
# 0                                       Avatar
# 1  Pirates of the Caribbean: On Stranger Tides
# 2                                 Dark Phoenix
# 3                      Avengers: Age of Ultron
# 4                       Avengers: Infinity War
#
#                                  primary_title  \
# 0                                       Avatar
# 1  Pirates of the Caribbean: On Stranger Tides
# 2                                 Dark Phoenix
# 3                      Avengers: Age of Ultron
# 4                       Avengers: Infinity War
#
#                                 original_title                    genres  \
# 0                                        Abatâ                    Horror
# 1  Pirates of the Caribbean: On Stranger Tides  Action,Adventure,Fantasy
# 2                                 Dark Phoenix   Action,Adventure,Sci-Fi
# 3                      Avengers: Age of Ultron   Action,Adventure,Sci-Fi
# ...

# %%
condensed_profit.sort_values(by=['net_profit_margin'], ascending=False).head(15)
# Out:
#                                 movie                    primary_title  \
# 3751                      The Gallows                      The Gallows
# 3535                            Bambi                            Bambi
# 2965         Night of the Living Dead         Night of the Living Dead
# 3452                            Rocky                            Rocky
# 3453                            Rocky                            Rocky
# 2047                        Halloween                        Halloween
# 3401  Snow White and the Seven Dwarfs  Snow White and the Seven Dwarfs
# 3400  Snow White and the Seven Dwarfs  Snow White and the Seven Dwarfs
# 3454                 The Devil Inside                 The Devil Inside
# 2417            The Birth of a Nation            The Birth of a Nation
# 3683                   Graduation Day                   Graduation Day
# 411                        Cinderella                       Cinderella
# ...

# %%
condensed_profit.sort_values(by=['profit'], ascending=False, inplace=True)

# %%
condensed_profit[condensed_profit.duplicated(subset=['movie'])]
# Out:
#                     movie         primary_title        original_title  \
# 43                Titanic               Titanic               Titanic
# 157                Frozen                Frozen   Wai nei chung ching
# 156                Frozen                Frozen                Frozen
# 137  Beauty and the Beast  Beauty and the Beast  Beauty and the Beast
# 136  Beauty and the Beast  Beauty and the Beast  Beauty and the Beast
# ..                    ...                   ...                   ...
# 465           The Promise           The Promise           The Promise
# 464           The Promise           The Promise           The Promise
# 463           The Promise           The Promise           The Promise
# 461           The Promise           The Promise           The Promise
# 460           The Promise           The Promise           The Promise
#
#                      genres  production_budget  domestic_gross  \
# ...

# %%
genres = list(condensed_profit['genres'].iloc[:100])

top_100_profit_genre_list = []

for genre in genres:
    each_genre = genre.split(',')
    for index in range(len(each_genre)):
        top_100_profit_genre_list.append(each_genre[index])

top_100_profit_genre_dict = {}
for genre in top_100_profit_genre_list:
    if genre in top_100_profit_genre_dict.keys():
        top_100_profit_genre_dict[genre] += 1
    else:
        top_100_profit_genre_dict[genre] = 1
        

top_100_profit_genre_dict = dict(sorted(top_100_profit_genre_dict.items(), key=lambda x : x[1], reverse=True))
top_100_profit_genre_dict
# Out:
# {'Adventure': 66,
#  'Action': 44,
#  'Sci-Fi': 26,
#  'Fantasy': 23,
#  'Comedy': 22,
#  'Animation': 19,
#  'Drama': 16,
#  'Family': 12,
#  'Thriller': 11,
#  'Musical': 5,
#  'Horror': 4,
#  'Crime': 4,
#  'Romance': 4,
#  'Documentary': 4,
#  'Sport': 2,
#  'Biography': 2,
#  'Music': 1,
#  'History': 1,
#  'Mystery': 1}

# %%
fig, ax = plt.subplots(figsize=(8, 10))

x = list(top_100_profit_genre_dict.keys())
height = list(top_100_profit_genre_dict.values())

ax.barh(x, height)
ax.set_title('Genres in Top 100 Profited Movies')
ax.set_xlabel('Number of Genre')
ax.set_ylabel('Genre')
# Out:
# Text(0, 0.5, 'Genre')

# %%
top_100_profit_genre_set_list = list(condensed_profit['genres'].iloc[:100])

top_100_profit_genre_set_dict = {}
for genre in top_100_profit_genre_set_list:
    if genre in top_100_profit_genre_set_dict.keys():
        top_100_profit_genre_set_dict[genre] += 1
    else:
        top_100_profit_genre_set_dict[genre] = 1

top_100_profit_genre_set_dict = dict(sorted(top_100_profit_genre_set_dict.items(), key=lambda x : x[1], reverse=True))
top_100_profit_genre_set_dict
# Out:
# {'Action,Adventure,Sci-Fi': 21,
#  'Adventure,Animation,Comedy': 14,
#  'Action,Adventure,Fantasy': 7,
#  'Action,Adventure,Comedy': 5,
#  'Family,Fantasy,Musical': 4,
#  'Horror': 3,
#  'Action,Crime,Thriller': 3,
#  'Adventure,Family,Fantasy': 3,
#  'Family': 2,
#  'Drama,Fantasy,Romance': 2,
#  'Action,Adventure,Animation': 2,
#  'Action,Adventure,Thriller': 2,
#  'Documentary': 2,
#  'Adventure,Fantasy': 2,
#  'Adventure,Drama,Fantasy': 2,
#  'Adventure,Drama,Sci-Fi': 2,
#  'Adventure': 1,
#  'Fantasy,Romance': 1,
#  'Adventure,Drama,Sport': 1,
#  'Adventure,Animation,Drama': 1,
#  'Biography,Drama,Music': 1,
#  'Fantasy,Musical': 1,
#  'Action,Thriller': 1,
#  'Animation': 1,
#  'Adventure,Drama,Family': 1,
#  'Thriller': 1,
#  'Action,Sci-Fi,Thriller': 1,
#  'Drama': 1,
#  'Crime,Drama': 1,
#  'Biography,Documentary,History': 1,
#  'Sci-Fi': 1,
#  'Documentary,Drama,Sport': 1,
#  'Horror,Thriller': 1,
#  'Drama,Sci-Fi,Thriller': 1,
#  'Action,Adventure,Family': 1,
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 10))

x = list(top_100_profit_genre_set_dict.keys())
height = list(top_100_profit_genre_set_dict.values())

ax.barh(x, height)
ax.set_title('Set of Genres in Top 100 Profited Movies')
ax.set_xlabel('Number of Set Genre')
ax.set_ylabel('Set Genre')
# Out:
# Text(0, 0.5, 'Set Genre')

# %% [markdown]
# genre by rating

# %%
genre_rating = title_basics.merge(title_ratings, on='tconst')
genre_rating.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
genre_rating = genre_rating[genre_rating['numvotes'] > 50000]

# %%
genre_rating = genre_rating.sort_values(by=['averagerating'], ascending=False)

# %%
genre_rating.head(15)
# Out:
#           tconst                      primary_title  \
# 56850  tt5813916                    The Mountain II
# 2387   tt1375666                          Inception
# 43420  tt4154796                  Avengers: Endgame
# 280    tt0816692                       Interstellar
# 2770   tt1424432                              Senna
# 7125   tt1675434                   The Intouchables
# 26774  tt2582802                           Whiplash
# 50962  tt5074352                             Dangal
# 47436  tt4633694  Spider-Man: Into the Spider-Verse
# 43419  tt4154756             Avengers: Infinity War
# 2241   tt1345836              The Dark Knight Rises
# 53087  tt5311514                         Your Name.
# 23663  tt2380307                               Coco
# 12072  tt1853728                   Django Unchained
# 1591   tt1255953                          Incendies
#
#                           original_title  start_year  runtime_minutes  \
# ...

# %%
genres2 = list(genre_rating['genres'].iloc[:100])

top_100_profit_genre_list2 = []

for genre in genres2:
    each_genre = genre.split(',')
    for index in range(len(each_genre)):
        top_100_profit_genre_list2.append(each_genre[index])

top_100_profit_genre_dict2 = {}
for genre in top_100_profit_genre_list2:
    if genre in top_100_profit_genre_dict2.keys():
        top_100_profit_genre_dict2[genre] += 1
    else:
        top_100_profit_genre_dict2[genre] = 1
        

top_100_profit_genre_dict2 = dict(sorted(top_100_profit_genre_dict2.items(), key=lambda x : x[1], reverse=True))
top_100_profit_genre_dict2
# Out:
# {'Drama': 67,
#  'Action': 29,
#  'Adventure': 26,
#  'Comedy': 26,
#  'Biography': 18,
#  'Crime': 15,
#  'Thriller': 14,
#  'Sci-Fi': 13,
#  'Mystery': 9,
#  'Animation': 8,
#  'Romance': 8,
#  'Music': 6,
#  'Fantasy': 6,
#  'Documentary': 5,
#  'History': 5,
#  'Sport': 3,
#  'War': 2,
#  'Family': 2,
#  'Western': 1}

# %%
fig, ax = plt.subplots(figsize=(8, 10))

x = list(top_100_profit_genre_dict2.keys())
height = list(top_100_profit_genre_dict2.values())

ax.barh(x, height)
ax.set_title('Genres for Top 100 Movies Ratings')
ax.set_xlabel('Number of Genre')
ax.set_ylabel('Genre')
# Out:
# Text(0, 0.5, 'Genre')

# %%
top_100_profit_genre_set_list2 = list(genre_rating['genres'].iloc[:100])

top_100_profit_genre_set_dict2 = {}
for genre in top_100_profit_genre_set_list2:
    if genre in top_100_profit_genre_set_dict2.keys():
        top_100_profit_genre_set_dict2[genre] += 1
    else:
        top_100_profit_genre_set_dict2[genre] = 1

top_100_profit_genre_set_dict2 = dict(sorted(top_100_profit_genre_set_dict2.items(), key=lambda x : x[1], reverse=True))
top_100_profit_genre_set_dict2
# Out:
# {'Action,Adventure,Sci-Fi': 6,
#  'Drama': 6,
#  'Adventure,Animation,Comedy': 5,
#  'Biography,Drama,History': 4,
#  'Action,Adventure,Comedy': 4,
#  'Biography,Comedy,Drama': 3,
#  'Drama,Thriller': 3,
#  'Comedy,Drama': 3,
#  'Drama,Romance': 3,
#  'Adventure,Drama,Sci-Fi': 2,
#  'Action,Biography,Drama': 2,
#  'Action,Adventure,Animation': 2,
#  'Crime,Drama,Mystery': 2,
#  'Action,Drama': 2,
#  'Crime,Drama': 2,
#  'Mystery,Thriller': 2,
#  'Biography,Drama': 2,
#  'Comedy,Drama,Romance': 2,
#  'Adventure,Drama,Fantasy': 2,
#  'Comedy,Drama,Music': 2,
#  'Action,Crime,Thriller': 2,
#  'Action,Crime,Drama': 2,
#  'Drama,Mystery,Sci-Fi': 2,
#  'Action,Drama,War': 1,
#  'Biography,Documentary,Sport': 1,
#  'Drama,Music': 1,
#  'Action,Thriller': 1,
#  'Animation,Drama,Fantasy': 1,
#  'Drama,Western': 1,
#  'Drama,Mystery,War': 1,
#  'Crime,Documentary': 1,
#  'Biography,Crime,Drama': 1,
#  'Action,Comedy,Crime': 1,
#  'Biography,Documentary,Music': 1,
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 10))

x = list(top_100_profit_genre_set_dict2.keys())
height = list(top_100_profit_genre_set_dict2.values())

ax.barh(x, height)
ax.set_title('Set of Genres in Top 100 Profited Movies')
ax.set_xlabel('Number of Set Genre')
ax.set_ylabel('Set Genre')
# Out:
# Text(0, 0.5, 'Set Genre')
